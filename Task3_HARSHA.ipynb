# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Final Olympic Game Data.csv')

# %%
df.head(5)
# Out:
#    ID                      Name Gender   Age  Height  Weight    Year  \
# 0   1                 A Dijiang      M  24.0   180.0    80.0  1992.0
# 1   2                  A Lamusi      M  23.0   170.0    60.0  2012.0
# 2   3       Gunnar Nielsen Aaby      M  24.0     NaN     NaN  1920.0
# 3   4      Edgar Lindenau Aabye      M  34.0     NaN     NaN  1900.0
# 4   5  Christine Jacoba Aaftink      F  21.0   185.0    82.0  1988.0
#
#         Region Region Code Region Notes  Season        Games Hosting City  \
# 0        China         CHN          NaN  Summer  1992 Summer    Barcelona
# 1        China         CHN          NaN  Summer  2012 Summer       London
# 2      Denmark         DEN          NaN  Summer  1920 Summer    Antwerpen
# 3      Denmark         DEN          NaN  Summer  1900 Summer        Paris
# 4  Netherlands         NED          NaN  Winter  1988 Winter      Calgary
#
#            Sport                               Event Medal
# ...

# %%
df.tail(5)
# Out:
#           ID                        Name Gender   Age  Height  Weight    Year  \
# 23853  12524  Fernande Bochatay (-Frank)      F  22.0   163.0    57.0  1968.0
# 23854  12524  Fernande Bochatay (-Frank)      F  18.0   163.0    57.0  1964.0
# 23855  12524  Fernande Bochatay (-Frank)      F  18.0   163.0    57.0  1964.0
# 23856  12524  Fernande Bochatay (-Frank)      F  22.0   163.0    57.0  1968.0
# 23857  12524                          Fe    NaN   NaN     NaN     NaN     NaN
#
#             Region Region Code Region Notes  Season        Games Hosting City  \
# 23853  Switzerland         SUI          NaN  Winter  1968 Winter     Grenoble
# 23854  Switzerland         SUI          NaN  Winter  1964 Winter    Innsbruck
# 23855  Switzerland         SUI          NaN  Winter  1964 Winter    Innsbruck
# 23856  Switzerland         SUI          NaN  Winter  1968 Winter     Grenoble
# 23857          NaN         NaN          NaN     NaN          NaN          NaN
#
# ...
